# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.sparse import csr_matrix
from sklearn.metrics import davies_bouldin_score

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## import and merge two datasets

# %%
df=pd.read_csv('song_data.csv')
df.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
df=df.drop_duplicates(['song_id'])

# %%
Num_Play = pd.read_csv('10000.txt', sep='\t', header=None, names=['user','song_id','play_count'])
Num_Play.head()
# Out:
#                                        user             song_id  play_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1

# %%
df_merge= pd.merge(Num_Play,df, how='left',on='song_id')
df_merge.head()
# Out:
#                                        user             song_id  play_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
title =df_merge.groupby(['title'])['play_count'].count().sort_values(ascending=False)
title=title.to_frame().head(20)
title
# Out:
#                                                     play_count
# title
# Sehr kosmisch                                             8277
# Undo                                                      7032
# Dog Days Are Over (Radio Edit)                            6949
# You're The One                                            6729
# Revelry                                                   6145
# Secrets                                                   5841
# Horn Concerto No. 4 in E flat K495: II. Romance...        5385
# Fireflies                                                 4795
# Hey_ Soul Sister                                          4758
# Tive Sim                                                  4548
# Use Somebody                                              3976
# OMG                                                       3947
# Drop The World                                            3879
# Marry Me                                                  3578
# Canada                                                    3526
# Catch You Baby (Steve Pitron & Max Sanna Radio ...        3511
# The Scientist                                             3372
# Just Dance                                                3222
# Pursuit Of Happiness (nightmare)                          3218
# Bulletproof                                               3152

# %%
fig = plt.figure(figsize=(50, 25))
a1 = fig.add_subplot(221)
f1 = title.plot(kind='bar', title='Top 20 Most Popular Songs', legend=False, ax=a1)
plt.xticks(rotation='vertical')
plt.ylabel('Item count')
# Out:
# Text(0, 0.5, 'Item count')

# %% [markdown]
# ## Recommend system item_based collaborative

# %% [markdown]
# ## 1.NearestNeighbors

# %%
df = df_merge[['song_id','user']].groupby(['song_id']).agg(['count']).sort_values(('user','count'),ascending=False)

plt.figure(figsize=(15,8))

sns.set_style("darkgrid")

sns.lineplot(data=df[('user', 'count')].values)

plt.title("Rating frequency of movies")

plt.xlabel("Movie id")

plt.ylabel("Number of listening");

# %%
min_ratings = 150

print("Number of songs which have more than {} listening: {}".format(min_ratings, len(df[df[('user', 'count')]>=min_ratings])))
# Out:
# Number of songs which have more than 150 listening: 3892

# %%
df_top_songs = df[df[('user', 'count')]>=min_ratings]

df_ratings_with_top_songs = df_merge[df_merge['song_id'].isin(list(df_top_songs.index))]

# %%
min_songs_rated = 150

df_users = df_ratings_with_top_songs[['song_id','user']].groupby(['user']).agg(['count']).sort_values(('song_id','count'),ascending=False)

df_top_rating_users = df_users[df_users[('song_id', 'count')]>=min_songs_rated]

top_rating_users = list(df_top_rating_users.index)

df_final=df_ratings_with_top_songs[df_ratings_with_top_songs['user'].isin(top_rating_users)]

# %%
df_user_item_matrix = df_final.pivot(index='song_id',columns='user',values='play_count').fillna(0)

# %%
user_item_matrix_sparse = csr_matrix(df_user_item_matrix.values)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model = NearestNeighbors(n_neighbors=30, metric='cosine', algorithm='brute', n_jobs=-1)

model.fit(user_item_matrix_sparse)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=30)

# %%
index_to_song = dict()

df_titles_song = df_merge.set_index('song_id').loc[df_user_item_matrix.index]

count = 0

for index, row in df_titles_song.iterrows():

    index_to_song[count]=row['title']

    count +=1


def recommender(model, user_item_matrix_sparse, df_merge, number_of_recommendations, song_index):

    main_title = index_to_song[song_index]

    dist, ind = model.kneighbors(user_item_matrix_sparse[song_index], n_neighbors=number_of_recommendations+1)

    dist = dist[0].tolist()

    ind = ind[0].tolist()

    titles = []

    for index in ind:

        titles.append(index_to_song[index])

    recommendations = list(zip(titles,dist))    

    # sort recommendations

    recommendations_sorted = sorted(recommendations, key = lambda x:x[1])

    # reverse recommendations, leaving out the first element 

    recommendations_sorted.reverse()

    recommendations_sorted = recommendations_sorted[:-1]

    print("10 Recommendations for song {}: ".format(main_title))

    count = 0

    for (title, distance) in recommendations_sorted:

        count += 1

        print('{}. {}, recommendation score = {}'.format(count, title, round(distance,3)))

recommender(model, user_item_matrix_sparse, df_merge, 10, 1)
# Out:
# 10 Recommendations for song Rome Wasn't Built In A Day:
# 1. STARSTRUKK [FEATURINGKATYPERRY] (Explicit Bonus Version), recommendation score = 0.461
# 2. 221, recommendation score = 0.461
# 3. Juke Box Hero (Remastered LP Version ), recommendation score = 0.446
# 4. Hallelujah (Album Version), recommendation score = 0.438
# 5. I Hate Everything About You, recommendation score = 0.413
# 6. STARSTRUKK [FEATURINGKATYPERRY] (Explicit Bonus Version), recommendation score = 0.401
# 7. Rome Wasn't Built In A Day, recommendation score = 0.384
# 8. Rome Wasn't Built In A Day, recommendation score = 0.378
# 9. Rome Wasn't Built In A Day, recommendation score = 0.375
# 10. STARSTRUKK [FEATURINGKATYPERRY] (Explicit Bonus Version), recommendation score = 0.357

# %% [markdown]
# # 2.Corrwith method

# %%
song_user = df_merge.groupby('user')['song_id'].count()

#Try to filter the user who listan more than 150
song_more20 = song_user[song_user >150].index.to_list()
df_song_id_more_ten = df_merge[df_merge['user'].isin(song_more20)].reset_index(drop=True)

# %%
matrix = df_song_id_more_ten.pivot_table(index=['user'], columns='title', values='play_count').fillna(0)
matrix
# Out:
# title                                     #!*@ You Tonight [Featuring R. Kelly] (Explicit Album Version)  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                                                0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                                                0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                                                0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                                                1.0
# 009fab78deabfd28481ce0123f5a9894c094d971                                                0.0
# ...                                                                                     ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                                                0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                                                0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                                                0.0
# fff03efd1550136063389fa71125194614e1c68f                                                0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                                                0.0
#
# title                                     #40  & Down  ' Cello Song  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401  0.0     0.0           0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4  0.0     0.0           0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67  0.0     0.0           0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64  0.0     0.0           0.0
# 009fab78deabfd28481ce0123f5a9894c094d971  0.0     0.0           0.0
# ...                                       ...     ...           ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be  0.0     0.0           0.0
# ffd458f903d49854685cf4540245c1d297e8bafa  0.0     0.0           0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046  0.0     0.0           0.0
# fff03efd1550136063389fa71125194614e1c68f  0.0     0.0           0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63  0.0     0.0           0.0
#
# title                                     '97 Bonnie & Clyde  'Round Midnight  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                 0.0              0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                 0.0              0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                 0.0              0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                 1.0              0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                 0.0              0.0
# ...                                                      ...              ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                 0.0              0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                 0.0              0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                 0.0              0.0
# fff03efd1550136063389fa71125194614e1c68f                 0.0              0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                 0.0              0.0
#
# title                                     'Til We Die (Album Version)  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                          0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                          0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                          0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                          0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                          0.0
# ...                                                               ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                          0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                          0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                          0.0
# fff03efd1550136063389fa71125194614e1c68f                          0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                          0.0
#
# title                                     'Till I Collapse  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401               0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4               0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67               0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64               0.0
# 009fab78deabfd28481ce0123f5a9894c094d971               0.0
# ...                                                    ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be               1.0
# ffd458f903d49854685cf4540245c1d297e8bafa               0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046               0.0
# fff03efd1550136063389fa71125194614e1c68f               0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63               0.0
#
# title                                     ('Til) I Kissed You  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                  0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                  0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                  0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                  0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                  0.0
# ...                                                       ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                  0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                  0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                  0.0
# fff03efd1550136063389fa71125194614e1c68f                  0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                  0.0
#
# title                                     (Anaesthesia) Pulling Teath  ...  \
# user                                                                   ...
# 00185e316f07f0f00c325ca034be59c15b362401                          0.0  ...
# 003d0f3aac94fd261bb74c0124a90750579972d4                          0.0  ...
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                          0.0  ...
# 007a631c3627babb8fb84d654b2d651c6c471c64                          0.0  ...
# 009fab78deabfd28481ce0123f5a9894c094d971                          0.0  ...
# ...                                                               ...  ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                          0.0  ...
# ffd458f903d49854685cf4540245c1d297e8bafa                          0.0  ...
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                          0.0  ...
# fff03efd1550136063389fa71125194614e1c68f                          0.0  ...
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                          0.0  ...
#
# title                                     sillyworld (Album Version)  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                         0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                         0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                         0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                         0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                         0.0
# ...                                                              ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                         0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                         0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                         0.0
# fff03efd1550136063389fa71125194614e1c68f                         0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                         0.0
#
# title                                     sleep_ eat food_ have visions  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                            0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                            0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                            0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                            0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                            0.0
# ...                                                                 ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                            0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                            0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                            0.0
# fff03efd1550136063389fa71125194614e1c68f                            0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                            0.0
#
# title                                     smile around the face  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                    0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                    0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                    0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                    0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                    0.0
# ...                                                         ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                    0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                    0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                    0.0
# fff03efd1550136063389fa71125194614e1c68f                    0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                    0.0
#
# title                                     sun drums and soil  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                 0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                 0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                 0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                 0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                 0.0
# ...                                                      ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                 0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                 0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                 0.0
# fff03efd1550136063389fa71125194614e1c68f                 0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                 0.0
#
# title                                     teachme (Album Version)  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                      0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                      0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                      0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                      0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                      0.0
# ...                                                           ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                      0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                      0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                      0.0
# fff03efd1550136063389fa71125194614e1c68f                      0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                      0.0
#
# title                                     the Love Song  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401            0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4            0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67            0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64            0.0
# 009fab78deabfd28481ce0123f5a9894c094d971            0.0
# ...                                                 ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be            0.0
# ffd458f903d49854685cf4540245c1d297e8bafa            0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046            0.0
# fff03efd1550136063389fa71125194614e1c68f            2.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63            0.0
#
# title                                     you were there with me  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                     0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                     0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                     0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                     0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                     0.0
# ...                                                          ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                     0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                     0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                     0.0
# fff03efd1550136063389fa71125194614e1c68f                     0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                     0.0
#
# title                                     ¡Viva La Gloria! (Album Version)  \
# user
# 00185e316f07f0f00c325ca034be59c15b362401                               0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                               0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                               0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                               0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                               0.0
# ...                                                                    ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                               0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                               0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                               0.0
# fff03efd1550136063389fa71125194614e1c68f                               0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                               0.0
#
# title                                     ¿Lo Ves? [Piano Y Voz]  Época
# user
# 00185e316f07f0f00c325ca034be59c15b362401                     0.0    0.0
# 003d0f3aac94fd261bb74c0124a90750579972d4                     0.0    0.0
# 00544d8bde0d7985e8d703c1eb676d41cad33c67                     0.0    0.0
# 007a631c3627babb8fb84d654b2d651c6c471c64                     0.0    0.0
# 009fab78deabfd28481ce0123f5a9894c094d971                     0.0    0.0
# ...                                                          ...    ...
# ffc564b85d81f0ea427cee3eea2415cc2fc5c4be                     0.0    0.0
# ffd458f903d49854685cf4540245c1d297e8bafa                     0.0    0.0
# ffdaab327f2fc6b9fa01a4e3e7f41fdd0e468046                     0.0    0.0
# fff03efd1550136063389fa71125194614e1c68f                     0.0    0.0
# fff6c30c773e6ffafcac213c9afd9666afaf6d63                     0.0    0.0
#
# [2409 rows x 9562 columns]

# %% [markdown]
# ## Test Item_based collborative

# %%
Undo_title=matrix['Undo']

# %%
Undo_music=pd.DataFrame(matrix.corrwith(Undo_title),columns=['correlations']).sort_values(by=['correlations'],ascending=False)

# %%
Undo_music.head(10)
# Out:
#                                                     correlations
# title
# Undo                                                    1.000000
# Horn Concerto No. 4 in E flat K495: II. Romance...      0.552071
# Catch You Baby (Steve Pitron & Max Sanna Radio ...      0.510228
# Drop The World                                          0.493327
# Sehr kosmisch                                           0.492029
# You're The One                                          0.491186
# Secrets                                                 0.486267
# Hey_ Soul Sister                                        0.440228
# Fireflies                                               0.434770
# If I Had You                                            0.426933

# %% [markdown]
# ## User_based collaborative and make sparse matrix

# %%
user_song_list_listen = df_merge[['user','play_count']].groupby('user').sum().reset_index()
user_song_list_listen.rename(columns={'play_count':'total_play'},inplace=True)
merged = pd.merge(df_merge,user_song_list_listen).sort_values(by='play_count',ascending=False)
merged=merged[merged['play_count']>30]

merged
# Out:
#                                              user             song_id  \
# 1228366  d13609d62db6df876d3cc388225478618bb7b912  SOFCGSE12AF72A674F
# 1048310  50996bbabb6f7857bf0c8019435b5246a0e45cfd  SOUAGPQ12A8AE47B3A
# 1586780  5ea608df0357ec4fda191cb9316fe8e6e65e3777  SOKOSPK12A8C13C088
# 31179    bb85bb79612e5373ac714fcd4469cabeb5ed94e1  SOZQSVB12A8C13C271
# 1875121  c012ec364329bb08cbe3e62fe76db31f8c5d8ec3  SOBONKR12A58A7A7E0
# ...                                           ...                 ...
# 901275   a31b11c667e351b4e15368538e6623be93d63676  SOQLVIT12A8C137EA2
# 204929   a2f600b2831a6d6ac7110c22fc8773d96a95aebd  SONDKOF12A6D4F7D70
# 1931775  7edc9d6c880eec6f25cfd6b888518d7b06fbec61  SOZBZSY12A6D4FA404
# 932240   63f18e848b9adadb5db81392f206f46b47ea28f4  SOPQDHP12A8C1346E2
# 215269   9e8dc6a1d1b4e02cb97ef82614bd81e805bb07fb  SOWYYUQ12A6701D68D
#
#          play_count                             title  \
# 1228366        2213                         Starshine
# 1048310         920              Crack Under Pressure
# 1586780         879       Call It Off (Album Version)
# 31179           796                 Paradise & Dreams
# 1875121         683                    You're The One
# ...             ...                               ...
# 901275           31          Sleep Through The Static
# 204929           31  Recado Falado (Metrô Da Saudade)
# 1931775          31                    Boys Don't Cry
# 932240           31                  Hei okei mä meen
# 215269           31                      It's My Life
#
#                                                    release       artist_name  \
# 1228366                                           Gorillaz          Gorillaz
# 1048310                    Stress related / Live and learn    Righteous Pigs
# 1586780                                            The Con    Tegan And Sara
# 31179                                            Skydivin'     Darren Styles
# 1875121                                 If There Was A Way     Dwight Yoakam
# ...                                                    ...               ...
# 901275                            Sleep Through The Static      Jack Johnson
# 204929                                              2 Em 1     Alceu Valença
# 1931775  Starter For 10: Original Motion Picture Soundt...          The Cure
# 932240                                         Karkuteillä  Karkkiautomaatti
# 215269                                               Crush          Bon Jovi
#
#          year  total_play
# 1228366  2000        2686
# 1048310  1998         988
# 1586780  2007        2032
# 31179       0         964
# 1875121  1990        1712
# ...       ...         ...
# 901275   2008         216
# 204929      0         136
# 1931775  1979         325
# 932240   1995         281
# 215269   2000         338
#
# [14384 rows x 8 columns]

# %%
merged=merged.drop(['release','year'],axis=1)

# %%
# Calculate the score of music that each user how much listen to a music from total
merged['score'] =merged['play_count']/merged['total_play']
merged.sort_values(by='play_count',ascending=False)
# Out:
#                                              user             song_id  \
# 1228366  d13609d62db6df876d3cc388225478618bb7b912  SOFCGSE12AF72A674F
# 1048310  50996bbabb6f7857bf0c8019435b5246a0e45cfd  SOUAGPQ12A8AE47B3A
# 1586780  5ea608df0357ec4fda191cb9316fe8e6e65e3777  SOKOSPK12A8C13C088
# 31179    bb85bb79612e5373ac714fcd4469cabeb5ed94e1  SOZQSVB12A8C13C271
# 1875121  c012ec364329bb08cbe3e62fe76db31f8c5d8ec3  SOBONKR12A58A7A7E0
# ...                                           ...                 ...
# 1101189  947c44d62da1c4c633b44204d3a41bd17848e67e  SOZSWRJ12A6D4FC3AB
# 492468   b2bc8e23a46c5d8e0db0639e0a2a7f7fa0a79d5c  SOBONKR12A58A7A7E0
# 25158    b08c89c2ba53c413375602b3d4687d4f9b260593  SOYPWKK12A8C136494
# 25154    b08c89c2ba53c413375602b3d4687d4f9b260593  SOOJWBH12A6D4F64E3
# 215269   9e8dc6a1d1b4e02cb97ef82614bd81e805bb07fb  SOWYYUQ12A6701D68D
#
#          play_count                              title            artist_name  \
# 1228366        2213                          Starshine               Gorillaz
# 1048310         920               Crack Under Pressure         Righteous Pigs
# 1586780         879        Call It Off (Album Version)         Tegan And Sara
# 31179           796                  Paradise & Dreams          Darren Styles
# 1875121         683                     You're The One          Dwight Yoakam
# ...             ...                                ...                    ...
# 1101189          31              Heart Attack and Vine  Screamin' Jay Hawkins
# 492468           31                     You're The One          Dwight Yoakam
# 25158            31  Ready_ Steady_ Go (Album Version)         Paul Oakenfold
# 25154            31                          Mongoloid                   Devo
# 215269           31                       It's My Life               Bon Jovi
#
#          total_play     score
# 1228366        2686  0.823902
# 1048310         988  0.931174
# 1586780        2032  0.432579
# 31179           964  0.825726
# 1875121        1712  0.398949
# ...             ...       ...
# 1101189         143  0.216783
# 492468          512  0.060547
# 25158           215  0.144186
# 25154           215  0.144186
# 215269          338  0.091716
#
# [14384 rows x 7 columns]

# %%
user_codes = merged.user.drop_duplicates().reset_index()
user_codes.rename(columns={'index':'user_index'}, inplace=True)
user_codes['user_idx'] = list(user_codes.index)

# %%
song_codes =merged.song_id.drop_duplicates().reset_index()
song_codes.rename(columns={'index':'song_idx'}, inplace=True)
song_codes['song_idx'] = list(song_codes.index)

# %%
new_set = pd.merge(merged,song_codes,how='left')
new_set = pd.merge(new_set,user_codes,how='left')
final = new_set[['user_idx','song_idx','score']]

# %% [markdown]
# ## Recommended engine with SVD matrix

# %%
data_array = final.score.values
row_array = final.user_idx.values
col_array =final.song_idx.values
data_sparse = coo_matrix((data_array, (row_array, col_array)),dtype=float)

# %%
from scipy.sparse.linalg import svds
import math as mt
from scipy.sparse import csc_matrix
from scipy.sparse.linalg import *
from scipy.sparse import coo_matrix

# %%
def compute_svd(urm, K):
    U, s, Vt = svds(urm, K)

    dim = (len(s), len(s))
    S = np.zeros(dim, dtype=np.float32)
    for i in range(0, len(s)):
        S[i,i] = mt.sqrt(s[i])

    U = csc_matrix(U, dtype=np.float32)
    S = csc_matrix(S, dtype=np.float32)
    Vt = csc_matrix(Vt, dtype=np.float32)
    
    return U, S, Vt

# %%
def compute_estimated_matrix(urm, U, S, Vt, uTest, K, test):
    rightTerm = S*Vt 
    estimatedRatings = np.zeros(shape=(MAX_UID, MAX_PID), dtype=np.float16)
    for userTest in uTest:
        prod = U[userTest, :]*rightTerm
        estimatedRatings[userTest, :] = prod.todense()
        recomendRatings = (-estimatedRatings[userTest, :]).argsort()[:250]
    return recomendRatings[1:]

# %%
K=50
urm = data_sparse
MAX_PID = urm.shape[1]
MAX_UID = urm.shape[0]

U, S, Vt = compute_svd(urm, K)
uTest = [8]

recommended_song = compute_estimated_matrix(urm, U, S, Vt, uTest, K, True)

# %%
print(f"The top five recommended song for user {new_set['user'][uTest]} is:")
for idx in recommended_song[:6]:
    for i,j in enumerate(new_set['song_idx']):
        # print(j)
        if idx==j:
            print( new_set['title'][idx])
            break
# Out:
# The top five recommended song for user 8    f5363481018dc87e8b06f9451e99804610a594fa
# Name: user, dtype: object is:
# Casting A Spell (Remixed) (1998 Digital Remaster)
# Funkytown
# Breakfast At Tiffany's
# Alma De Diamante
# Mala Vida
# You're The One
